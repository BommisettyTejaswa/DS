# %%
import numpy as np
import matplotlib.pyplot as plt
Order_time=[1,1,2,1,3]
Delivery_time=[10,15,20,15,25]
Delivery_partner=["Swiggy","swiggy","zomato","Swiggy","Zomato"]
Customer_ratings=[5,4,3,4,3]
temp=0
temp1=0
count=0
count1=0
count2=0
temp2=0
count3=0
temp3=0
print("===  Dataset Loaded ===")
for i in range(len(Order_time)):
    print("Order_time:",Order_time[i],"Delivery_time:",Delivery_time[i],"Delivery_partner:",Delivery_partner[i],"Customer_ratings:",Customer_ratings[i])
for i in range(len(Order_time)):
  if Delivery_partner[i]=="Swiggy":
    temp=temp+Delivery_time[i]
    count=count+1
avg_delivery_time=temp/count
print("Average Delivary time of swiggy:",avg_delivery_time)
for i in range(len(Order_time)):
  if Delivery_partner[i]=="Zomato":
    temp=temp+Delivery_time[i]
    count1=count1+1
avg_delivery_time1=temp/count1
print("Average Delivary time of zomato:",avg_delivery_time1)
most_delayed_partner=max(avg_delivery_time,avg_delivery_time1)
if most_delayed_partner==avg_delivery_time:
  print("Most delayed  is swiggy")
else:
  print("Most delayed  is zomato")
from collections import Counter
peak_order_hours = Counter(Order_time).most_common(1)[0][0]
print("Peak order hours:",peak_order_hours)
for i in range(len(Order_time)):
  if Delivery_partner[i]=="Swiggy":
    temp2=temp2+Customer_ratings[i]
    count2=count2+1
rating_ofswiggy=temp2/count2
print("Rating of swiggy:",rating_ofswiggy)
for i in range(len(Order_time)):
  if Delivery_partner[i]=="Zomato":
    temp3=temp3+Customer_ratings[i]
    count3=count3+1
rating_ofzomato=temp3/count3
print("Rating of zomato:",rating_ofzomato)
Top_rated_delivary_partner=max(rating_ofswiggy,rating_ofzomato)
if Top_rated_delivary_partner==rating_ofswiggy:
  print("Top rated delivary partner is swiggy")
else:
  print("Top rated delivary partner is zomato")
a=[]
a.append(rating_ofswiggy)
a.append(rating_ofzomato)
Delivery_partner_labels = ["Swiggy", "Zomato"]
plt.bar(Delivery_partner_labels,a)
plt.xlabel("Delivary partner")
plt.ylabel("Customer ratings")
plt.title("Top ratings of Delivery partners ")
plt.show()
# Out:
# ===  Dataset Loaded ===
# Order_time: 1 Delivery_time: 10 Delivery_partner: Swiggy Customer_ratings: 5
# Order_time: 1 Delivery_time: 15 Delivery_partner: swiggy Customer_ratings: 4
# Order_time: 2 Delivery_time: 20 Delivery_partner: zomato Customer_ratings: 3
# Order_time: 1 Delivery_time: 15 Delivery_partner: Swiggy Customer_ratings: 4
# Order_time: 3 Delivery_time: 25 Delivery_partner: Zomato Customer_ratings: 3
# Average Delivary time of swiggy: 12.5
# Average Delivary time of zomato: 50.0
# Most delayed  is zomato
# Peak order hours: 1
# Rating of swiggy: 4.5
# Rating of zomato: 3.0
# Top rated delivary partner is swiggy

# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
customer_name=["A","B","C","D","E"]
Product_purchase=["Mobile","Laptop","Mobile","Shoes","Bag Pack"]
Cart_abandoment=["No","Yes","No","No","Yes"]
Customer_ratings=[4.5,4,3.5,3,5]
Payments_methods=["Cash","UPI","Card","Cash","UPI"]
most_sold_products=Counter(Product_purchase).most_common(1)[0][0]
print("Most sold products:",most_sold_products)
most_used_payment_method=Counter(Payments_methods).most_common(1)[0][0]
print("Most used payment method:",most_used_payment_method)
for i in range(len(customer_name)):
  if Customer_ratings[i]<4:
    print(Product_purchase[i],"with poor rating")

payment_counts = Counter(Payments_methods)
payment_labels = list(payment_counts.keys())
payment_values = list(payment_counts.values())

plt.figure(figsize=(8, 5))
plt.bar(payment_labels, payment_values, color=['skyblue', 'lightcoral', 'lightgreen'])
plt.xlabel("Payment Method")
plt.ylabel("Frequency")
plt.title("Distribution of Payment Methods")
plt.show()
# Out:
# Most sold products: Mobile
# Most used payment method: Cash
# Mobile with poor rating
# Shoes with poor rating

# %%
import numpy as np
import matplotlib.pyplot as plt
Transaction_id=[14390,29824,39404,44839,58492]
Transaction_amount=[9000,5000,8000,20000,10000]
Location=["North","South","West","East"]
Time=[2,13,16,18,22]
Account_activity=["Debit","Credit","Transfer","Credit","Debit"]
for i in range(len(Transaction_amount)):
  if Time[i]>=0 and Time[i]<=2 or Time[i]>=22 and Time[i]<=23:
    print("The transaction ",Transaction_id[i],"id  is unusual")
# Out:
# The transaction  14390 id  is unusual
# The transaction  58492 id  is unusual
