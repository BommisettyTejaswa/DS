# %% [markdown]
# Int

# %%
a=90.2
b=int(a)
print(b)
type(b)
print(type(b))
# Out:
# 90
# <class 'int'>

# %% [markdown]
# Float

# %%
a=90.5
b=round(a,0)
print(b)
type(b)
# Out:
# 90.0
# float

# %% [markdown]
# String

# %%
a=12
b=str(a)
print(b)
print(type(b))
# Out:
# 12
# <class 'str'>

# %% [markdown]
# Bollean

# %%
b=True
print(b)
print(type(b))
# Out:
# True
# <class 'bool'>

# %% [markdown]
# Comlplex number

# %%
num = 3 + 4j
print("Complex Number:", num)
print("Type:", type(num))
# Out:
# Complex Number: (3+4j)
# Type: <class 'complex'>

# %% [markdown]
# List

# %%
fruits = ["Apple", "Banana", "Mango"]
print("Fruits:", fruits)
print("First Fruit:", fruits[0])
print("Type:", type(fruits))
# Out:
# Fruits: ['Apple', 'Banana', 'Mango']
# First Fruit: Apple
# Type: <class 'list'>

# %% [markdown]
# Tuple

# %%
colors = ("Red", "Green", "Blue")
print("Colors:", colors)
print("First Color:", colors[0])
print("Type:", type(colors))
# Out:
# Colors: ('Red', 'Green', 'Blue')
# First Color: Red
# Type: <class 'tuple'>

# %% [markdown]
# Set

# %%
numbers = {10, 20, 30, 20}
print("Numbers:", numbers)
print("Type:", type(numbers))
# Out:
# Numbers: {10, 20, 30}
# Type: <class 'set'>

# %% [markdown]
# Dictonary

# %%
student = {
    "Name": "Tejaswa",
    "Age": 20,
    "Course": "CSE"
}
print("Student:", student)
print("Name:", student["Name"])
print("Type:", type(student))
# Out:
# Student: {'Name': 'Tejaswa', 'Age': 20, 'Course': 'CSE'}
# Name: Tejaswa
# Type: <class 'dict'>
