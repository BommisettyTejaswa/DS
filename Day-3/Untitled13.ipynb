# %%
name_of_customer=["Hemanth","Rahul","Mohan","Ramesh","Santhosh"]
Internet_speed=[2,10,1,15,3]
Payment_failure=[3,0,4,0,2]
Delevary_charges=[200,50,250,40,180]
Purchase_completed=["False","True","False","True","False"]
print("===Dataset uploaded sucessfully===")
for i in range(len(name_of_customer)):
  print("Customer_name:",name_of_customer[i],"Internet_speed:",Internet_speed[i],"Payment_failure:",Payment_failure[i],"Delevary_charges:",Delevary_charges[i],"Purchase_completed:",Purchase_completed[i])
total_abandnment=Purchase_completed.count("False")
print("Total no of customers Abandment:",total_abandnment)
print("===Internet_Diagonasis===")
for i in range(len(name_of_customer)):
  if Internet_speed[i]<5:
    print(name_of_customer[i],Internet_speed[i],"Mbs")
print("===Payment_diagonasis===")
for i in range(len(name_of_customer)):
  if Payment_failure[i]>0:
    print(name_of_customer[i])
print("===Delivery Charges===")
for i in range(len(name_of_customer)):
  if Delevary_charges[i]>150:
    print(name_of_customer[i])
print("Root cause")
for i in range(len(name_of_customer)):
  if Purchase_completed[i]=="False":
    if Internet_speed[i]<5:
      print(name_of_customer[i])
    elif Payment_failure[i]>0:
      print(name_of_customer[i])
    elif Delevary_charges[i]>150:
      print(name_of_customer[i])
import matplotlib.pyplot as plt
plt.bar(name_of_customer,Delevary_charges)
plt.xlabel("name_of_customer")
plt.ylabel("Delivary_charges")
plt.title("Delivary_charges")
plt.show()
# Out:
# ===Dataset uploaded sucessfully===
# Customer_name: Hemanth Internet_speed: 2 Payment_failure: 3 Delevary_charges: 200 Purchase_completed: False
# Customer_name: Rahul Internet_speed: 10 Payment_failure: 0 Delevary_charges: 50 Purchase_completed: True
# Customer_name: Mohan Internet_speed: 1 Payment_failure: 4 Delevary_charges: 250 Purchase_completed: False
# Customer_name: Ramesh Internet_speed: 15 Payment_failure: 0 Delevary_charges: 40 Purchase_completed: True
# Customer_name: Santhosh Internet_speed: 3 Payment_failure: 2 Delevary_charges: 180 Purchase_completed: False
# Total no of customers Abandment: 3
# ===Internet_Diagonasis===
# Hemanth 2 Mbs
# Mohan 1 Mbs
# Santhosh 3 Mbs
# ===Payment_diagonasis===
# Hemanth
# Mohan
# Santhosh
# ===Delivery Charges===
# Hemanth
# Mohan
# Santhosh
# Root cause
# Hemanth
# Mohan
# Santhosh
